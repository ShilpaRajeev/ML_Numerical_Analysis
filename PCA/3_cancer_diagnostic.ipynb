# %% [markdown]
# # Serum proteomic pattern diagnostics
#
# Dataset from the FDA-NCI Clinical Proteomics Program Databank [1,2].
#
# Each column of `A` represents measurements taken from a patient. There are 216 columns representing 216 patients, out of which 121 are ovarian cancer patients and 95 are normal patients.
#
# Each row represents the ion intensity level at a specific mass-charge value indicated in MZ. There are 2000 mass-charge values, and each row represents the ion-intensity levels of the patients at that particular mass-charge value.
#
# The variable `grp` holds the index information as to which of these samples represent cancer patients and which ones represent normal patients.
#
# - [1] T.P. Conrads, et al., ["High-resolution serum proteomic features for ovarian detection"](https://doi.org/10.1677/erc.0.0110163), Endocrine-Related Cancer, 11, 2004, pp. 163-178.
# - [2] E.F. Petricoin, et al., ["Use of proteomic patterns in serum to identify ovarian cancer"](<https://doi.org/10.1016/s0140-6736(02)07746-2>), Lancet, 359(9306), 2002, pp. 572-577.

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

ovariancancer_obs_path = "./ovariancancer_obs.csv"
ovariancancer_grp_path = "./ovariancancer_grp.csv"

A = np.genfromtxt(ovariancancer_obs_path, delimiter=",").transpose()
with open(ovariancancer_grp_path, "r") as fp:
    grp = np.array(fp.read().split("\n"))
grp = grp[grp != ""]

# %% [markdown]
# How many patients? How many features?

# %%
n_features = A.shape[0]
n_patients = A.shape[1]
print(f"{n_features} features")
print(f"{n_patients} patients")
# Out:
# 4000 features
# 216 patients

# %% [markdown]
# How many patiens with and without cancer are there in the dataset?

# %%
print(f"{np.sum(grp == 'Cancer')} Cancer")
print(f"{np.sum(grp == 'Normal')} Normal")
print(f"Total: {grp.size}")
is_sane = np.where(grp == "Normal", 1, 0) #boolean vector, 1 for normal 0 for cancer
# Out:
# 121 Cancer
# 95 Normal
# Total: 216

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# Choose two proteins (between 1 and 2000), and make a scatterplot of the corresponding values plotting with different colors the data corresponding to patients with and without cancer. Can you easily distinguish between patients with/without cancer?

# %%
protein_x = 0
protein_y = 1

plt.scatter(
    A[protein_x, grp == "Cancer"], A[protein_y, grp == "Cancer"], label="Cancer"
)
plt.scatter(
    A[protein_x, grp == "Normal"], A[protein_y, grp == "Normal"], label="Normal"
)
plt.legend()
plt.show()

# %% [markdown]
# Repeat the previous point, this time by considering three proteins.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

protein_x = 1000
protein_y = 2000
protein_z = 3000

for label in ("Cancer", "Normal"):
    ax.scatter(
        A[protein_x, grp == label],
        A[protein_y, grp == label],
        A[protein_z, grp == label],
        label=label,
        marker="x",
        s=50,
    )
plt.legend()
ax.view_init(25, 20)

# %% [markdown]
# ## Principal Components Analysis

# %% [markdown]
# Perform PCA on the data. Then, plot the trend of
#
# - the singular values $\sigma_k$
# - the cumulate fraction of singular values: $\frac{\sum_{i=1}^{k} \sigma_i}{\sum_{i=1}^{q} \sigma_i}$
# - the fraction of the "explained variance": $\frac{\sum_{i=1}^{k} \sigma_i^2}{\sum_{i=1}^{q} \sigma_i^2}$

# %%
# SOLUTION-BEGIN
A_mean = A.mean(axis=1)
A_bar = A - A_mean[:, None]
U, s, VT = np.linalg.svd(A_bar, full_matrices=False)

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

axes[0].semilogy(s[:-1], "o-")
axes[0].set_title("Singluar values")

axes[1].plot(np.cumsum(s) / np.sum(s), "o-")
axes[1].set_title("Cumulate fraction of singular values")

axes[2].plot(np.cumsum(s**2) / np.sum(s**2), "o-")
axes[2].set_title("Explained variance")
# SOLUTION-END
# Out:
# Text(0.5, 1.0, 'Explained variance')

# %% [markdown]
# Make a scatterplot of the first two principal components of the patients.

# %%
# SOLUTION-BEGIN
Phi = U[:, :2].T @ A_bar
plt.scatter(Phi[0, :], Phi[1, :], marker="o", c=(grp == "Normal"), s=50)
plt.show()
# SOLUTION-END

# %% [markdown]
# Make a scatterplot of the first three principal components of the patients.

# %%
# SOLUTION-BEGIN
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
Phi = U[:, :3].T @ A_bar
ax.scatter(Phi[0, :], Phi[1, :], Phi[2, :], marker="x", c=(grp == "Normal"), s=50)
ax.view_init(25, 20)
plt.show()
# SOLUTION-END

# %% [markdown]
# Or more compactly, and with an interactive plot

# %%
import plotly.express as px

px.scatter_3d(x=Phi[0, :], y=Phi[1, :], z=Phi[2, :], color=grp)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="74f65bdb-5170-4ce7-b6d7-5f750ad73181" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74f65bdb-5170-4ce7-b6d7-5f750ad73181")) {                    Plotly.newPlot(                        "74f65bdb-5170-4ce7-b6d7-5f750ad73181",                        [{"hovertemplate":"color=Cancer\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cancer","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Cancer","scene":"scene","showlegend":true,"x":[-7.967050457270297,-9.232076037880827,-19.91617660801906,-12.532131293246048,-29.60900907659102,-22.251609973832394,12.405781914562981,2.7826081932361935,-15.120244803480482,-12.29392670697795,-31.03414446629113,-24.257070136624815,-19.804219099818305,15.419099688874784,9.376905075771448,-13.815030369756359,-18.88097396513682,-12.854222630702191,-16.487787245660975,-31.42765211117491,13.496044548759066,-15.258005310642023,9.621586949851514,-9.450758402703686,-5.378601714649254,-20.933737180121437,-10.627635969798222,-2.195951231638388,11.4050217579827,4.7870722027306005,4.420307763917226,-21.905102021448442,-13.265806954594984,-6.3965905319454865,6.907341908391846,1.8522215320418813,-5.917036193948367,-14.259414797584876,-42.502307829414235,-22.91572610187448,3.071346860058484,-1.43737521589697,-9.227074879037648,-2.5304045051312785,-7.5672724701443395,-13.96395772712335,-33.863875994448826,-2.1696136054097814,15.240392098532674,-9.573668211414521,11.591648246958316,6.610274017134317,5.508311053179926,3.263094296188497,9.576511164561515,15.783140107873727,12.051442226526017,8.907247632570119,-0.6993781243715489,3.6985251761777076,-11.262083452451343,10.253737455354205,-1.195274221263349,0.12560266418525615,-0.6958730247321483,-0.8501740856299129,-5.913710082376923,19.580047162379763,15.350837631083287,-13.593600632134695,3.1381386715408426,0.9256217213506933,-13.876408339364655,-9.884007268652478,-31.38985194863148,17.998631694588877,-13.07069008803432,13.673405414019363,11.04520850110345,-12.239078713608313,-28.83809501160726,-25.315664037168958,-39.14135120538586,7.627328852951837,3.6862362577773506,-19.7117186748843,-11.821562608514158,-22.939785557913005,13.1076313358944,0.9902819732230378,-17.052846736706382,-17.153570816516094,-17.315747823238254,-26.01845525350996,11.208437865900606,-10.68793346988211,-9.02349112946775,-13.887938138571766,-9.16882838665498,3.9762867579176513,7.29635789895406,-8.26539727713971,-16.415500326808964,-12.675521628934298,-26.50851492416884,8.450539834141347,-31.402006766413496,0.12695433366057923,-18.151060994932,-10.920242326351483,-13.465493506691566,-13.813173067111217,-8.241587021005003,-21.24460450682018,-8.094212601276077,-12.55093357774869,-5.659737300023792,8.372957598254882,-0.3577647384253128,3.3229268330208432,-1.9852703307879525],"y":[-1.2725382641677245,0.3015628874839531,-0.48113507364526537,-0.7712842342311494,9.2452729732252,9.293472031007703,3.3108010569183626,-1.551805579839845,-2.1338072058879263,-2.8636229934236788,-6.207404134115487,-1.912559572641554,-1.6162622398727005,4.359553603798513,0.36836620919498647,-2.3977129229263636,-2.7031796404937802,-2.0593711283237677,-3.3461491280341624,1.0128880733595076,3.86148922861324,0.960677439759347,-1.1401923440298227,-1.7131397005078426,-0.5183971644726232,0.056092627787226464,-1.3001757598578827,3.5058696738182697,-1.8642815823300405,-0.8111574673241113,-1.0496501471800497,-1.72341576002028,7.135728774103694,-0.5319127728693253,4.471779009371454,1.2198748208928811,0.8692997615695675,2.871177134853117,1.7588744502173057,-0.6401547773282538,1.3654742419533512,-0.8351704796079157,-1.1065989890224082,0.72062751 ...

# %% [markdown]
# Visualize the protein components of the first three principal components

# %%
# SOLUTION-BEGIN
plt.plot(U[:, 0:3])
plt.legend(["PC1", "PC2", "PC3"])
plt.xlabel("Biomarker ID")
plt.ylabel("Importance")
# SOLUTION-END
# Out:
# Text(0, 0.5, 'Importance')

# %% [markdown]
# The following is a generalization of the thresholding algorithm we have seen in the previous notebook for higher dimensions: instead of a vertical line, think to a plane in 3D that separates the two groups. The implementation of this classification algorithm (SVC) will be an argument of Lab04. For now, we just use this (SVC) as a tool  from a library. We care only about the output training accuracy.

# %%
from sklearn.svm import SVC


def classify(X, labels):
    clf = SVC(kernel="linear")
    clf.fit(X.T, labels)
    y_pred = clf.predict(X.T)
    accuracy = np.mean(y_pred == labels)
    print(f"Training accuracy: {accuracy:.2f}")

classify(Phi, is_sane)
# Out:
# Training accuracy: 0.83
